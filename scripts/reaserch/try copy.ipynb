# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## initialize

# %%
X = np.arange(0, 100)
Y = np.random.random(size=[100])

# %% [markdown]
# ## plot

# %%
plt.plot(X, Y)
